],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff9600ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff9600ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_0d7203ac5a14103746265f370b64f941);
#
#
#             var poly_line_45433fb2921062c

# %% [markdown]
# ### Marker, Icon, Popup

# %%
m2 = folium.Map([0, 0], zoom_start=1)
mk2 = features.Marker([0, 0])
pp2 = folium.Popup("hello")
ic2 = features.Icon(color="red")

mk2.add_child(ic2)
mk2.add_child(pp2)
m2.add_child(mk2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71e80ee8e62d8e7cbcecf9256e163a47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71e80ee8e62d8e7cbcecf9256e163a47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_71e80ee8e62d8e7cbcecf9256e163a47 = L.map(
#                 &quot;map_71e80ee8e62d8e7cbcecf9256e163a47&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8f8d84afddc3bcd82f249f0c67e3278 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71e80ee8e62d8e7cbcecf9256e163a47);
#
#
#             var marker_60c82fd33cd332f65a9090c4a4514290 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_71e80ee8e62d8e7cbcecf9256e163a47);
#
#
#             var icon_007c01ab564a21d67198a1cd6b711816 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_60c82fd33cd332f65a9090c4a4514290.setIcon(icon_007c01ab564a21d67198a1cd6b711816);
#
#
#         var popup_adeb85d87ef169243481bd2b41aefc9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_89ebe39515112b22c7a6b628bd738781 = $(`&lt;div id=&quot;html_89ebe39515112b22c7a6b628bd738781&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hello&lt;/div&gt;`)[0];
#             popup_adeb85d87ef169243481bd2b41aefc9f.setContent(html_89ebe39515112b22c7a6b628bd738781);
#
#
#         marker_60c82fd33cd332f65a9090c4a4514290.bindPopup(popup_adeb85d87ef169243481bd2b41aefc9f)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Vega popup

# %%
import json
#!pip install vincent
import vincent

N = 100

multi_iter2 = {
    "x": np.random.uniform(size=(N,)),
    "y": np.random.uniform(size=(N,)),
}

scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=100, width=200)
data = json.loads(scatter.to_json())

m3 = folium.Map([0, 0], zoom_start=1)
mk3 = features.Marker([0, 0])
p = folium.Popup("Hello")
v = features.Vega(data, width="100%", height="100%")

mk3.add_child(p)
p.add_child(v)
m3.add_child(mk3)

m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a580e788054f239168d5a9e4175f520 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_399a9bf15cd7504b006a019d2050415e {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a580e788054f239168d5a9e4175f520&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9a580e788054f239168d5a9e4175f520 = L.map(
#                 &quot;map_9a580e788054f239168d5a9e4175f520&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecb9365aeb50339d953f15d34b110550 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a580e788054f239168d5a9e4175f520);
#
#
#             var marker_13204c66456805e4a3cd1b1cb506a981 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_9a580e788054f239168d5a9e4175f520);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_e373cc0a42b9b1c4bb8fa22353fa513b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6086d6e91633b05d69bfa43d880a04bf = $(`&lt;div id=&quot;html_6086d6e91633b05d69bfa43d880a04bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hello&lt;/div&gt;`)[0];
#             popup_e373cc0a42b9b1c4bb8fa22353fa513b.setContent(html_6086d6e91633b05d69bfa43d880a04bf);
#
#             var vega_399a9bf15cd7504b006a019d2050415e = $(`             &lt;div id=&quot;vega_399a9bf15cd7504b006a019d2050415e&quot;&gt;&lt;/div&gt;             `)[0];
#             popup_e373cc0a42b9b1c4bb8fa22353fa513b.setContent(vega_399a9bf15cd7504b006a019d2050415e);
#
#
#         marker_13204c66456805e4a3cd1b1cb506a981.bindPopup(popup_e373cc0a42b9b1c4bb8fa22353fa513b)
#         ;
#
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7066561496190843, &quot;val&quot;: 0.8384294965057433}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8129070204425183, &quot;val&quot;: 0.5490247556665477}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6324964860941633, &quot;val&quot;: 0.7989919062187825}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8606326866715818, &quot;val&quot;: 0.41153117522325333}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.602552656654765, &quot;val&quot;: 0.40456649645849274}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5265402727466075, &quot;val&quot;: 0.6365323360407884}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5877920953067879, &quot;val&quot;: 0.18494027726317075}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.05232301983522647, &quot;val&quot;: 0.36410923694338915}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.2858087988219734, &quot;val&quot;: 0.8895165692581176}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1389773728647875, &quot;val&quot;: 0.2054510883982441}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8625774974876196, &quot;val&quot;: 0.4884855528158314}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.31413323843750107, &quot;val&quot;: 0.9362172041678058}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1873787291661959, &quot;val&quot;: 0.08282202624865309}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.3019795085785252, &quot;val&quot;: 0.04619740403150063}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.878599907852986, &quot;val&quot;: 0.5363420752020851}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.12541069315217201, &quot;val&quot;: 0.9164171091226879}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.3016126475490042, &quot;val&quot;: 0.03315676334645756}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8086720235090312, &quot;val&quot;: 0.9650068453243038}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9689593549215467, &quot;val&quot;: 0.9749280092615237}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5874831251120279, &quot;val&quot;: 0.7823393218163782}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.210136109472161, &quot;val&quot;: 0.7916726661194464}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.3213939737237945, &quot

# %% [markdown]
# ### Vega-Lite popup

# %%
#!pip install altair
#!pip install vega_datasets
from altair import Chart, load_dataset
from vega_datasets import data
# load built-in dataset as a pandas DataFrame
cars = data.cars()

scatter = (
    Chart(cars)
    .mark_circle()
    .encode(
        x="Horsepower",
        y="Miles_per_Gallon",
        color="Origin",
    )
)

vega = folium.features.VegaLite(
    scatter,
    width="100%",
    height="100%",
)

m4 = folium.Map(location=[-27.5717, -48.6256])

marker = folium.features.Marker([-27.57, -48.62])

popup = folium.Popup()

vega.add_to(popup)
popup.add_to(marker)

marker.add_to(m4)

m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eee3b4caefad68ece335a5a43dae2cf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_0471f90df52bfcd0d35fc9c0747b85a6 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega@3&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@2&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@3&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eee3b4caefad68ece335a5a43dae2cf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eee3b4caefad68ece335a5a43dae2cf8 = L.map(
#                 &quot;map_eee3b4caefad68ece335a5a43dae2cf8&quot;,
#                 {
#                     center: [-27.5717, -48.6256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5752ac9166a5608ce4ffc1136fa79d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eee3b4caefad68ece335a5a43dae2cf8);
#
#
#             var marker_22d11667950d6c5db19a3128906205a6 = L.marker(
#                 [-27.57, -48.62],
#                 {}
#             ).addTo(map_eee3b4caefad68ece335a5a43dae2cf8);
#
#
#         var popup_2f0a17c34cc1f8cac02713b8955f50ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var vega_lite_0471f90df52bfcd0d35fc9c0747b85a6 = $(`             &lt;div id=&quot;vega_lite_0471f90df52bfcd0d35fc9c0747b85a6&quot;&gt;&lt;/div&gt;             `)[0];
#             popup_2f0a17c34cc1f8cac02713b8955f50ea.setContent(vega_lite_0471f90df52bfcd0d35fc9c0747b85a6);
#
#
#         marker_22d11667950d6c5db19a3128906205a6.bindPopup(popup_2f0a17c34cc1f8cac02713b8955f50ea)
#         ;
#
#
#
#                     vegaEmbed(vega_lite_0471f90df52bfcd0d35fc9c0747b85a6, {&quot;$schema&quot;: &quot;https://vega.github.io/schema/vega-lite/v4.17.0.json&quot;, &quot;config&quot;: {&quot;view&quot;: {&quot;continuousHeight&quot;: 300, &quot;continuousWidth&quot;: 400}}, &quot;data&quot;: {&quot;name&quot;: &quot;data-f02450ab61490a1363517a0190416235&quot;}, &quot;datasets&quot;: {&quot;data-f02450ab61490a1363517a0190416235&quot;: [{&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 307.0, &quot;Horsepower&quot;: 130.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;chevrolet chevelle malibu&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3504, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 350.0, &quot;Horsepower&quot;: 165.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;buick skylark 320&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3693, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 318.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;plymouth satellite&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3436, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 304.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 16.0, &quot;Name&quot;: &quot;amc rebel sst&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3433, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 302.0, &quot;Horsepower&quot;: 140.0, &quot;Miles_per_Gallon&quot;: 17.0, &quot;Name&quot;: &quot;ford torino&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3449, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 429.0, &quot;Horsepower&quot;: 198.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;ford galaxie 500&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4341, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 9.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 454.0, &quot;Horsepower&quot;: 220.0, &quot;Miles_per_Gallon&quot;: 14.0, &quot;Name&quot;: &quot;chevrolet impala&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4354, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 8.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 440.0, &quot;Horsepower&quot;: 215.0, &quot;Miles_per_Gallon&quot;: 14.0, &quot;Name&quot;: &quot;plymouth fury iii&quot;

# %% [markdown]
# ### Vega div and a Map

# %%
import branca

N = 100

multi_iter2 = {
    "x": np.random.uniform(size=(N,)),
    "y": np.random.uniform(size=(N,)),
}

scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=250, width=420)
data = json.loads(scatter.to_json())

f = branca.element.Figure()

# Create two maps.
m5 = folium.Map(
    location=[0, 0],
    tiles="stamenwatercolor",
    zoom_start=1,
    position="absolute",
    left="0%",
    width="50%",
    height="50%",
)

m6 = folium.Map(
    location=[46, 3],
    tiles="OpenStreetMap",
    zoom_start=4,
    position="absolute",
    left="50%",
    width="50%",
    height="50%",
    top="50%",
)

# Create two Vega.
v5 = features.Vega(data, position="absolute", left="50%", width="50%", height="50%")

v6 = features.Vega(
    data, position="absolute", left="0%", width="50%", height="50%", top="50%"
)

f.add_child(m5)
f.add_child(m6)
f.add_child(v5)
f.add_child(v6)

f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_036fc2db46a0155deeee9790595ad3be {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_994e7bd8025076b551cfa050af918327 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 50.0%;
#                     top: 50.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_2c59aeec71164a774d775920ca627c97 {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 50.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_709b4044b03d8ac9e25bcd9979baf19a {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 0.0%;
#                 top: 50.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_036fc2db46a0155deeee9790595ad3be&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_994e7bd8025076b551cfa050af918327&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_2c59aeec71164a774d775920ca627c97&quot;&gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_709b4044b03d8ac9e25bcd9979baf19a&quot;&gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_036fc2db46a0155deeee9790595ad3be = L.map(
#                 &quot;map_036fc2db46a0155deeee9790595ad3be&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb32239617a0a09cf325d6e9f22161e5 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_036fc2db46a0155deeee9790595ad3be);
#
#
#             var map_994e7bd8025076b551cfa050af918327 = L.map(
#                 &quot;map_994e7bd8025076b551cfa050af918327&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de00bf15d855b17e8aff35315d893239 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_994e7bd8025076b551cfa050af918327);
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6471162907020812, &quot;val&quot;: 0.3386892544970529}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6708464010816502, &quot;val&quot;: 0.34608037471119724}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.509576765077148, &quot;val&quot;: 0.8965721165910917}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1870639558631536, &quot;val&quot;: 0.1869329166930408}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9385391938938747, &quot;val&quot;: 0.9346950585537841}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8463665937677596, &quot;val&quot;: 0.40160426758114653}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5339754412965796, &quot;val&quot;: 0.7376630724552002}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6326136566931452, &quot;val&quot;: 0.5380040883990734}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.17580243031299325, &quot;val&quot;: 0.07156293450963258}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.520104100897539, &quot;val&quot

# %% [markdown]
# ### Vega-Lite div and a Map

# %%
import pandas as pd

N = 100

multi_iter2 = pd.DataFrame(
    {
        "x": np.random.uniform(size=(N,)),
        "y": np.random.uniform(size=(N,)),
    }
)

scatter = Chart(multi_iter2).mark_circle().encode(x="x", y="y")
scatter.width = 420
scatter.height = 250
data = json.loads(scatter.to_json())

f = branca.element.Figure()

# Create two maps.
m7 = folium.Map(
    location=[0, 0],
    tiles="stamenwatercolor",
    zoom_start=1,
    position="absolute",
    left="0%",
    width="50%",
    height="50%",
)

m8 = folium.Map(
    location=[46, 3],
    tiles="OpenStreetMap",
    zoom_start=4,
    position="absolute",
    left="50%",
    width="50%",
    height="50%",
    top="50%",
)


# Create two Vega.
v7 = features.VegaLite(data, position="absolute", left="50%", width="50%", height="50%")

v8 = features.VegaLite(
    data, position="absolute", left="0%", width="50%", height="50%", top="50%"
)

f.add_child(m7)
f.add_child(m8)
f.add_child(v7)
f.add_child(v8)

f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b11de4f87018fde0ab00a06b75ea044e {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ffc37f8430f181b8c194d4922f435be {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 50.0%;
#                     top: 50.0%;
#                 }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_f49e11e9a0ef25403e56255d56c425fc {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 50.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega@3&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@2&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@3&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_lite_26b595fa62fa2e21927162b970f15d29 {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 0.0%;
#                 top: 50.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b11de4f87018fde0ab00a06b75ea044e&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ffc37f8430f181b8c194d4922f435be&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_lite_f49e11e9a0ef25403e56255d56c425fc&quot;&gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_lite_26b595fa62fa2e21927162b970f15d29&quot;&gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b11de4f87018fde0ab00a06b75ea044e = L.map(
#                 &quot;map_b11de4f87018fde0ab00a06b75ea044e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b66bdce998610968394040bebfc24863 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b11de4f87018fde0ab00a06b75ea044e);
#
#
#             var map_9ffc37f8430f181b8c194d4922f435be = L.map(
#                 &quot;map_9ffc37f8430f181b8c194d4922f435be&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f621d9af0fdc306842ed0d4fb5ef157 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9ffc37f8430f181b8c194d4922f435be);
#
#
#                     vegaEmbed(vega_lite_f49e11e9a0ef25403e56255d56c425fc, {&quot;$schema&quot;: &quot;https://vega.github.io/schema/vega-lite/v4.17.0.json&quot;, &quot;config&quot;: {&quot;view&quot;: {&quot;continuousHeight&quot;: 300, &quot;continuousWidth&quot;: 400}}, &quot;data&quot;: {&quot;name&quot;: &quot;data-e314385b2bf0f238e952d70eea61ae61&quot;}, &quot;datasets&quot;: {&quot;data-e314385b2bf0f238e952d70eea61ae61&quot;: [{&quot;x&quot;: 0.8820761928161627, &quot;y&quot;: 0.27606263828320765}, {&quot;x&quot;: 0.4577042060882929, &quot;y&quot;: 0.09768125457408483}, {&quot;x&quot;: 0.40505261548961413, &quot;y&quot;: 0.31589800135315727}, {&quot;x&quot;: 0.36897151265713146, &quot;y&quot;: 0.11434845895089574}, {&quot;x&quot;: 0.1191939571658518, &quot;y&quot;: 0.19595554235305046}, {&quot;x&quot;: 0.2594065759971519, &quot;y&quot;: 0.7657350014773734}, {&quot;x&quot;: 0.3382860681737151, &quot;y&quot;: 0.25986608859459204}, {&quot;x&quot;: 0.37793348098281776, &quot;y&quot;: 0.15311037862083055}, {&quot;x&quot;: 0.8414269013854561, &quot;y&quot;: 0.5683977381695464}, {&quot;x&quot;: 0.44277985474075576, &quot;y&quot;: 0.8036103891605081}, {&quot;x&quot;: 0.7278093909058946, &quot;y&quot;: 0.9077582866946804}, {&quot;x

# %% [markdown]
# ### GeoJson

# %%
N = 1000

lons = +5 - np.random.normal(size=N)
lats = 48 - np.random.normal(size=N)

data = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "type": "MultiPoint",
                "coordinates": [[lon, lat] for (lat, lon) in zip(lats, lons)],
            },
            "properties": {"prop0": "value0"},
        },
    ],
}

m9 = folium.Map([48, 5], zoom_start=6)
m9.add_child(features.GeoJson(data))

m9
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5f35ed3dc45f46a627c73915bce54c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5f35ed3dc45f46a627c73915bce54c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e5f35ed3dc45f46a627c73915bce54c8 = L.map(
#                 &quot;map_e5f35ed3dc45f46a627c73915bce54c8&quot;,
#                 {
#                     center: [48.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3199e813e240b41aa2a5af5e5a3fd1b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e5f35ed3dc45f46a627c73915bce54c8);
#
#
#
#         function geo_json_ba2e7723d0d2ab7de842c609bc92ab85_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_
# %% [markdown]
# ### Div

# %%
N = 100

multi_iter2 = {
    "x": np.random.uniform(size=(N,)),
    "y": np.random.uniform(size=(N,)),
}

scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=250, width=420)
data = json.loads(scatter.to_json())

f = branca.element.Figure()

d1 = f.add_subplot(1, 2, 1)
d2 = f.add_subplot(1, 2, 2)

d1.add_child(folium.Map([0, 0], tiles="stamenwatercolor", zoom_start=1))
d2.add_child(folium.Map([46, 3], tiles="OpenStreetMap", zoom_start=5))

f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd906da61c5d2a90cd4b2e7b3b5b43f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;style&gt; #div_3eb3ef0693e27754d6650581ae25b342 {
#         position : absolute;
#         width : 45.0%;
#         height: 90.0%;
#         left: 2.5%;
#         top: 5.0%;
#     &lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_660a8c79eb509863394392cf4e932cf5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;style&gt; #div_b4c5f288b96922824e0339e47975f794 {
#         position : absolute;
#         width : 45.0%;
#         height: 90.0%;
#         left: 52.5%;
#         top: 5.0%;
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;div id=&quot;div_3eb3ef0693e27754d6650581ae25b342&quot;&gt;
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd906da61c5d2a90cd4b2e7b3b5b43f9&quot; &gt;&lt;/div&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;div_b4c5f288b96922824e0339e47975f794&quot;&gt;
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_660a8c79eb509863394392cf4e932cf5&quot; &gt;&lt;/div&gt;
#         &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fd906da61c5d2a90cd4b2e7b3b5b43f9 = L.map(
#                 &quot;map_fd906da61c5d2a90cd4b2e7b3b5b43f9&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d4821e665b144c0d21b5215435bf90f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd906da61c5d2a90cd4b2e7b3b5b43f9);
#
#
#             var map_660a8c79eb509863394392cf4e932cf5 = L.map(
#                 &quot;map_660a8c79eb509863394392cf4e932cf5&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8995277998425d318b522f9585a846a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_660a8c79eb509863394392cf4e932cf5);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### LayerControl

# %%
m11 = folium.Map(tiles=None)

folium.raster_layers.TileLayer("OpenStreetMap").add_to(m11)
folium.raster_layers.TileLayer("stamentoner").add_to(m11)

folium.LayerControl().add_to(m11)

m11
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_468995a40cf98d09d36914ce45c1e10d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_468995a40cf98d09d36914ce45c1e10d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_468995a40cf98d09d36914ce45c1e10d = L.map(
#                 &quot;map_468995a40cf98d09d36914ce45c1e10d&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_376e3703f8dd001779b6e188de1a76cc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_468995a40cf98d09d36914ce45c1e10d);
#
#
#             var tile_layer_43f2b7b02a0db677b5931b13f57e1c00 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_468995a40cf98d09d36914ce45c1e10d);
#
#
#             var layer_control_23bf1e51cbdbcb9a65e3ac3bb3c00294 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_376e3703f8dd001779b6e188de1a76cc,
#                     &quot;stamentoner&quot; : tile_layer_43f2b7b02a0db677b5931b13f57e1c00,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_23bf1e51cbdbcb9a65e3ac3bb3c00294.base_layers,
#                 layer_control_23bf1e51cbdbcb9a65e3ac3bb3c00294.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_468995a40cf98d09d36914ce45c1e10d);
#             tile_layer_43f2b7b02a0db677b5931b13f57e1c00.remove();
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
